# %%
# !git clone https://github.com/pytorch/examples.git
# %cd examples/word_language_model
# Out:
# fatal: destination path 'examples' already exists and is not an empty directory.
# /content/examples/word_language_model

# %% [markdown]
# 1. (10’) Run the code with its default configurations to obtain test PPL’s for LSTM and transformer
# models. Include all intermediate results, e.g., training and validation losses

# %%
# !python main.py --cuda --epochs 6
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch  8.45 | loss  7.63 | ppl  2049.07
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  5.24 | loss  6.85 | ppl   945.27
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  5.31 | loss  6.47 | ppl   648.03
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  5.31 | loss  6.28 | ppl   536.05
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  5.27 | loss  6.13 | ppl   459.86
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  5.30 | loss  6.05 | ppl   425.14
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  5.25 | loss  5.94 | ppl   378.58
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch  5.26 | loss  5.94 | ppl   379.52
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch  5.27 | loss  5.80 | ppl   329.19
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch  5.24 | loss  5.78 | ppl   322.66
# ...

# %% [markdown]
# 2. (20’) We now vary the “bptt” length, while keeping all the other configurations same as question 1.
# Plot test PPL’s of LSTM and transformer for a range of “bptt” lengths, and discuss the results.

# %%
lstm_ppls = []

# %%
# !python main.py --cuda --epochs 6 --bptt 10
# Out:
# | epoch   1 |   200/10443 batches | lr 20.00 | ms/batch  5.66 | loss  7.72 | ppl  2262.24
# | epoch   1 |   400/10443 batches | lr 20.00 | ms/batch  2.46 | loss  6.92 | ppl  1012.22
# | epoch   1 |   600/10443 batches | lr 20.00 | ms/batch  2.46 | loss  6.62 | ppl   753.15
# | epoch   1 |   800/10443 batches | lr 20.00 | ms/batch  2.47 | loss  6.46 | ppl   636.13
# | epoch   1 |  1000/10443 batches | lr 20.00 | ms/batch  2.45 | loss  6.34 | ppl   567.52
# | epoch   1 |  1200/10443 batches | lr 20.00 | ms/batch  2.47 | loss  6.22 | ppl   501.78
# | epoch   1 |  1400/10443 batches | lr 20.00 | ms/batch  2.53 | loss  6.16 | ppl   472.11
# | epoch   1 |  1600/10443 batches | lr 20.00 | ms/batch  2.47 | loss  6.04 | ppl   420.07
# | epoch   1 |  1800/10443 batches | lr 20.00 | ms/batch  2.46 | loss  6.01 | ppl   408.44
# | epoch   1 |  2000/10443 batches | lr 20.00 | ms/batch  2.42 | loss  5.94 | ppl   378.65
# ...

# %%
lstm_ppls.append(161.15)

# %%
# !python main.py --cuda --epochs 6 --bptt 20
# Out:
# | epoch   1 |   200/ 5221 batches | lr 20.00 | ms/batch  6.95 | loss  7.64 | ppl  2069.97
# | epoch   1 |   400/ 5221 batches | lr 20.00 | ms/batch  3.56 | loss  6.86 | ppl   952.15
# | epoch   1 |   600/ 5221 batches | lr 20.00 | ms/batch  3.50 | loss  6.59 | ppl   727.78
# | epoch   1 |   800/ 5221 batches | lr 20.00 | ms/batch  3.53 | loss  6.33 | ppl   562.35
# | epoch   1 |  1000/ 5221 batches | lr 20.00 | ms/batch  3.50 | loss  6.18 | ppl   485.03
# | epoch   1 |  1200/ 5221 batches | lr 20.00 | ms/batch  3.51 | loss  6.06 | ppl   426.53
# | epoch   1 |  1400/ 5221 batches | lr 20.00 | ms/batch  3.55 | loss  6.02 | ppl   411.30
# | epoch   1 |  1600/ 5221 batches | lr 20.00 | ms/batch  3.55 | loss  5.94 | ppl   379.91
# | epoch   1 |  1800/ 5221 batches | lr 20.00 | ms/batch  3.54 | loss  5.91 | ppl   368.44
# | epoch   1 |  2000/ 5221 batches | lr 20.00 | ms/batch  3.53 | loss  5.85 | ppl   348.95
# ...

# %%
lstm_ppls.append(144.79)

# %%
# !python main.py --cuda --epochs 6 --bptt 30
# Out:
# | epoch   1 |   200/ 3481 batches | lr 20.00 | ms/batch  8.35 | loss  7.64 | ppl  2075.90
# | epoch   1 |   400/ 3481 batches | lr 20.00 | ms/batch  4.78 | loss  6.87 | ppl   963.75
# | epoch   1 |   600/ 3481 batches | lr 20.00 | ms/batch  4.71 | loss  6.54 | ppl   689.06
# | epoch   1 |   800/ 3481 batches | lr 20.00 | ms/batch  4.74 | loss  6.29 | ppl   536.48
# | epoch   1 |  1000/ 3481 batches | lr 20.00 | ms/batch  4.76 | loss  6.17 | ppl   476.67
# | epoch   1 |  1200/ 3481 batches | lr 20.00 | ms/batch  4.76 | loss  6.07 | ppl   433.40
# | epoch   1 |  1400/ 3481 batches | lr 20.00 | ms/batch  4.73 | loss  6.01 | ppl   405.52
# | epoch   1 |  1600/ 3481 batches | lr 20.00 | ms/batch  4.79 | loss  5.92 | ppl   372.95
# | epoch   1 |  1800/ 3481 batches | lr 20.00 | ms/batch  4.73 | loss  5.91 | ppl   369.72
# | epoch   1 |  2000/ 3481 batches | lr 20.00 | ms/batch  4.70 | loss  5.81 | ppl   333.42
# ...

# %%
lstm_ppls.append(139.26)

# %%
# !python main.py --cuda --epochs 6 --bptt 40
# Out:
# | epoch   1 |   200/ 2610 batches | lr 20.00 | ms/batch  9.49 | loss  7.64 | ppl  2072.11
# | epoch   1 |   400/ 2610 batches | lr 20.00 | ms/batch  5.85 | loss  6.86 | ppl   951.19
# | epoch   1 |   600/ 2610 batches | lr 20.00 | ms/batch  5.76 | loss  6.50 | ppl   664.64
# | epoch   1 |   800/ 2610 batches | lr 20.00 | ms/batch  5.79 | loss  6.29 | ppl   536.70
# | epoch   1 |  1000/ 2610 batches | lr 20.00 | ms/batch  5.77 | loss  6.16 | ppl   472.44
# | epoch   1 |  1200/ 2610 batches | lr 20.00 | ms/batch  5.77 | loss  6.05 | ppl   424.08
# | epoch   1 |  1400/ 2610 batches | lr 20.00 | ms/batch  5.78 | loss  5.99 | ppl   400.28
# | epoch   1 |  1600/ 2610 batches | lr 20.00 | ms/batch  5.82 | loss  5.86 | ppl   352.15
# | epoch   1 |  1800/ 2610 batches | lr 20.00 | ms/batch  5.79 | loss  5.82 | ppl   336.49
# | epoch   1 |  2000/ 2610 batches | lr 20.00 | ms/batch  5.79 | loss  5.68 | ppl   292.25
# ...

# %%
lstm_ppls.append(139.23)

# %%
# !python main.py --cuda --epochs 6 --bptt 50
# Out:
# | epoch   1 |   200/ 2088 batches | lr 20.00 | ms/batch  9.98 | loss  7.63 | ppl  2059.24
# | epoch   1 |   400/ 2088 batches | lr 20.00 | ms/batch  7.03 | loss  6.82 | ppl   917.26
# | epoch   1 |   600/ 2088 batches | lr 20.00 | ms/batch  6.97 | loss  6.49 | ppl   660.57
# | epoch   1 |   800/ 2088 batches | lr 20.00 | ms/batch  7.02 | loss  6.29 | ppl   536.88
# | epoch   1 |  1000/ 2088 batches | lr 20.00 | ms/batch  6.95 | loss  6.12 | ppl   456.69
# | epoch   1 |  1200/ 2088 batches | lr 20.00 | ms/batch  7.01 | loss  6.05 | ppl   422.64
# | epoch   1 |  1400/ 2088 batches | lr 20.00 | ms/batch  6.97 | loss  5.94 | ppl   378.43
# | epoch   1 |  1600/ 2088 batches | lr 20.00 | ms/batch  7.04 | loss  5.79 | ppl   326.94
# | epoch   1 |  1800/ 2088 batches | lr 20.00 | ms/batch  6.98 | loss  5.80 | ppl   329.10
# | epoch   1 |  2000/ 2088 batches | lr 20.00 | ms/batch  6.97 | loss  5.66 | ppl   288.53
# ...

# %%
lstm_ppls.append(142.05)

# %%
transformer_ppls = []

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 20 --bptt 10
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# | epoch   1 |   200/10443 batches | lr 20.00 | ms/batch  9.37 | loss 20.99 | ppl 1311230809.59
# | epoch   1 |   400/10443 batches | lr 20.00 | ms/batch  5.42 | loss 15.37 | ppl 4716328.91
# | epoch   1 |   600/10443 batches | lr 20.00 | ms/batch  5.43 | loss 11.50 | ppl 98463.54
# | epoch   1 |   800/10443 batches | lr 20.00 | ms/batch  5.49 | loss 10.34 | ppl 30898.80
# | epoch   1 |  1000/10443 batches | lr 20.00 | ms/batch  5.38 | loss  9.63 | ppl 15140.29
# | epoch   1 |  1200/10443 batches | lr 20.00 | ms/batch  5.43 | loss  9.06 | ppl  8613.66
# ...

# %%
transformer_ppls.append(1056.01)

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 20 --bptt 20
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# | epoch   1 |   200/ 5221 batches | lr 20.00 | ms/batch  8.88 | loss 20.22 | ppl 603159406.08
# | epoch   1 |   400/ 5221 batches | lr 20.00 | ms/batch  5.43 | loss 11.81 | ppl 135164.11
# | epoch   1 |   600/ 5221 batches | lr 20.00 | ms/batch  5.43 | loss 10.83 | ppl 50360.15
# | epoch   1 |   800/ 5221 batches | lr 20.00 | ms/batch  5.37 | loss 10.41 | ppl 33270.32
# | epoch   1 |  1000/ 5221 batches | lr 20.00 | ms/batch  5.45 | loss  9.40 | ppl 12113.72
# | epoch   1 |  1200/ 5221 batches | lr 20.00 | ms/batch  5.37 | loss  9.02 | ppl  8295.52
# ...

# %%
transformer_ppls.append(1015.43)

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 20 --bptt 30
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# | epoch   1 |   200/ 3481 batches | lr 20.00 | ms/batch  8.94 | loss 14.78 | ppl 2632871.87
# | epoch   1 |   400/ 3481 batches | lr 20.00 | ms/batch  5.61 | loss 11.87 | ppl 142354.22
# | epoch   1 |   600/ 3481 batches | lr 20.00 | ms/batch  5.38 | loss 10.41 | ppl 33241.29
# | epoch   1 |   800/ 3481 batches | lr 20.00 | ms/batch  5.46 | loss  9.57 | ppl 14386.12
# | epoch   1 |  1000/ 3481 batches | lr 20.00 | ms/batch  5.45 | loss  9.31 | ppl 11045.43
# | epoch   1 |  1200/ 3481 batches | lr 20.00 | ms/batch  5.44 | loss  9.24 | ppl 10352.55
# ...

# %%
transformer_ppls.append(991.88)

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 20 --bptt 40
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# | epoch   1 |   200/ 2610 batches | lr 20.00 | ms/batch  9.42 | loss 16.37 | ppl 12824764.97
# | epoch   1 |   400/ 2610 batches | lr 20.00 | ms/batch  6.10 | loss 13.90 | ppl 1092301.66
# | epoch   1 |   600/ 2610 batches | lr 20.00 | ms/batch  6.17 | loss 11.32 | ppl 82837.12
# | epoch   1 |   800/ 2610 batches | lr 20.00 | ms/batch  6.15 | loss 10.06 | ppl 23497.98
# | epoch   1 |  1000/ 2610 batches | lr 20.00 | ms/batch  6.21 | loss  9.51 | ppl 13511.22
# | epoch   1 |  1200/ 2610 batches | lr 20.00 | ms/batch  6.15 | loss  9.07 | ppl  8732.16
# ...

# %%
transformer_ppls.append(987.65)

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 20 --bptt 50
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# | epoch   1 |   200/ 2088 batches | lr 20.00 | ms/batch 11.46 | loss 17.83 | ppl 55264078.55
# | epoch   1 |   400/ 2088 batches | lr 20.00 | ms/batch  6.93 | loss 14.22 | ppl 1500593.77
# | epoch   1 |   600/ 2088 batches | lr 20.00 | ms/batch  7.01 | loss 11.07 | ppl 64204.39
# | epoch   1 |   800/ 2088 batches | lr 20.00 | ms/batch  7.01 | loss  9.92 | ppl 20239.14
# | epoch   1 |  1000/ 2088 batches | lr 20.00 | ms/batch  6.97 | loss  9.63 | ppl 15169.94
# | epoch   1 |  1200/ 2088 batches | lr 20.00 | ms/batch  6.98 | loss  9.41 | ppl 12176.60
# ...

# %%
transformer_ppls.append(520.01)

# %%
import matplotlib.pyplot as plt

bptt_lengths = [10, 20, 30, 40, 50]

plt.plot(bptt_lengths, lstm_ppls, label='LSTM')
plt.plot(bptt_lengths, transformer_ppls, label='Transformer')
plt.xlabel('BPTT Length')
plt.ylabel('Test PPL')
plt.title('Test BPTT Length VS Test PPL')
plt.legend()
plt.show()

# %% [markdown]
# 3. (30’) In this question, we always set word embedding dimension equal to the hidden dimension, i.e.,
# use the same value for “emsize” and “nhid” when calling main.py. Let us keep the default “bptt”, and
# vary “nhid” and “nlayers”. Report test PPL’s for all (“nhid”, “nlayers”) tuples. It is suggested to
# visualize2
# the PPL on 2D grids of “nhid”-“nlayers” coordindate, with a colorbar. Discuss the results.

# %%
# !python main.py --cuda --epochs 6 --emsize 200 --nhid 200 --nlayers 1
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:82: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch  7.61 | loss  7.51 | ppl  1827.24
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  4.41 | loss  6.64 | ppl   767.79
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  4.47 | loss  6.27 | ppl   526.23
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  4.49 | loss  6.11 | ppl   452.28
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  4.41 | loss  6.00 | ppl   403.73
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  4.41 | loss  5.94 | ppl   380.16
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  4.43 | loss  5.85 | ppl   345.66
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 200 --nhid 200 --nlayers 2
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch  8.66 | loss  7.63 | ppl  2049.07
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  5.25 | loss  6.85 | ppl   945.27
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  5.29 | loss  6.47 | ppl   648.03
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  5.19 | loss  6.28 | ppl   536.05
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  5.22 | loss  6.13 | ppl   459.86
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  5.20 | loss  6.05 | ppl   425.14
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  5.25 | loss  5.94 | ppl   378.58
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch  5.22 | loss  5.94 | ppl   379.52
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch  5.26 | loss  5.80 | ppl   329.19
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch  5.18 | loss  5.78 | ppl   322.66
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 1
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:82: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 10.52 | loss  7.51 | ppl  1823.92
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  6.66 | loss  6.58 | ppl   721.31
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  6.67 | loss  6.21 | ppl   497.36
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  6.63 | loss  6.06 | ppl   426.92
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  6.62 | loss  5.94 | ppl   378.26
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  6.65 | loss  5.86 | ppl   350.08
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  6.65 | loss  5.76 | ppl   317.93
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 2
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 10.97 | loss  7.70 | ppl  2215.09
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  7.70 | loss  6.82 | ppl   915.24
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  6.43 | ppl   621.26
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  7.63 | loss  6.23 | ppl   508.56
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.67 | loss  6.08 | ppl   436.07
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.64 | loss  5.99 | ppl   400.50
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.69 | loss  5.87 | ppl   353.65
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  5.87 | ppl   354.30
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.71 | loss  5.70 | ppl   300.12
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.69 | loss  5.66 | ppl   286.68
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 600 --nhid 600 --nlayers 1
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:82: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 11.94 | loss  7.55 | ppl  1899.13
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  8.57 | loss  6.57 | ppl   716.66
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  8.64 | loss  6.19 | ppl   489.82
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  8.62 | loss  6.03 | ppl   417.37
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  8.59 | loss  5.90 | ppl   364.57
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  8.57 | loss  5.81 | ppl   335.06
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  8.58 | loss  5.73 | ppl   306.90
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 600 --nhid 600 --nlayers 2
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 13.06 | loss  7.74 | ppl  2302.60
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  9.92 | loss  6.77 | ppl   872.32
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  9.82 | loss  6.36 | ppl   575.46
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  9.84 | loss  6.16 | ppl   471.85
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  9.83 | loss  6.01 | ppl   409.27
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  9.87 | loss  5.92 | ppl   373.07
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  9.82 | loss  5.81 | ppl   335.09
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch  9.84 | loss  5.81 | ppl   333.64
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch  9.83 | loss  5.63 | ppl   279.87
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch  9.82 | loss  5.60 | ppl   270.08
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

nhid_values = [200, 400, 600]
nlayers_values = [1, 2]
ppls_matrix = np.array([[143.00, 138.45],
                 [132.62, 128.74],
                 [131.45, 131.88]])

plt.imshow(ppls_matrix, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Test PPL')
plt.xticks(range(len(nlayers_values)), nlayers_values)
plt.yticks(range(len(nhid_values)), nhid_values)
plt.xlabel('Number of Layers')
plt.ylabel('Hidden Dimension')
plt.title('Test PPL for Different Hidden Dimensions and Number of Layers')
plt.show()

# %% [markdown]
# 4. (20’) (Length Generalization)3 Take the best ‘nhid”-“nlayers” configuration you get in question 3.
# Apply the corresponding model to test data, but with a varying “bptt”. This simulates a situation
# with length mismatch between training and testing. Discuss the results.

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 2 --bptt 10
# Out:
# | epoch   1 |   200/10443 batches | lr 20.00 | ms/batch  6.99 | loss  7.72 | ppl  2262.71
# | epoch   1 |   400/10443 batches | lr 20.00 | ms/batch  3.35 | loss  6.87 | ppl   967.65
# | epoch   1 |   600/10443 batches | lr 20.00 | ms/batch  3.37 | loss  6.54 | ppl   694.75
# | epoch   1 |   800/10443 batches | lr 20.00 | ms/batch  3.37 | loss  6.37 | ppl   581.90
# | epoch   1 |  1000/10443 batches | lr 20.00 | ms/batch  3.38 | loss  6.27 | ppl   526.09
# | epoch   1 |  1200/10443 batches | lr 20.00 | ms/batch  3.41 | loss  6.15 | ppl   468.01
# | epoch   1 |  1400/10443 batches | lr 20.00 | ms/batch  3.38 | loss  6.09 | ppl   442.27
# | epoch   1 |  1600/10443 batches | lr 20.00 | ms/batch  3.37 | loss  5.97 | ppl   391.17
# | epoch   1 |  1800/10443 batches | lr 20.00 | ms/batch  3.35 | loss  5.94 | ppl   379.97
# | epoch   1 |  2000/10443 batches | lr 20.00 | ms/batch  3.36 | loss  5.86 | ppl   349.87
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 2 --bptt 20
# Out:
# | epoch   1 |   200/ 5221 batches | lr 20.00 | ms/batch  8.07 | loss  7.66 | ppl  2116.54
# | epoch   1 |   400/ 5221 batches | lr 20.00 | ms/batch  5.01 | loss  6.81 | ppl   911.35
# | epoch   1 |   600/ 5221 batches | lr 20.00 | ms/batch  5.09 | loss  6.52 | ppl   676.14
# | epoch   1 |   800/ 5221 batches | lr 20.00 | ms/batch  5.03 | loss  6.27 | ppl   525.91
# | epoch   1 |  1000/ 5221 batches | lr 20.00 | ms/batch  5.07 | loss  6.12 | ppl   452.78
# | epoch   1 |  1200/ 5221 batches | lr 20.00 | ms/batch  5.03 | loss  5.97 | ppl   392.16
# | epoch   1 |  1400/ 5221 batches | lr 20.00 | ms/batch  5.07 | loss  5.92 | ppl   374.19
# | epoch   1 |  1600/ 5221 batches | lr 20.00 | ms/batch  5.08 | loss  5.85 | ppl   347.61
# | epoch   1 |  1800/ 5221 batches | lr 20.00 | ms/batch  5.02 | loss  5.79 | ppl   328.20
# | epoch   1 |  2000/ 5221 batches | lr 20.00 | ms/batch  5.03 | loss  5.73 | ppl   307.51
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 2 --bptt 30
# Out:
# | epoch   1 |   200/ 3481 batches | lr 20.00 | ms/batch  9.94 | loss  7.65 | ppl  2092.82
# | epoch   1 |   400/ 3481 batches | lr 20.00 | ms/batch  6.75 | loss  6.83 | ppl   925.93
# | epoch   1 |   600/ 3481 batches | lr 20.00 | ms/batch  6.74 | loss  6.46 | ppl   640.15
# | epoch   1 |   800/ 3481 batches | lr 20.00 | ms/batch  6.66 | loss  6.21 | ppl   499.13
# | epoch   1 |  1000/ 3481 batches | lr 20.00 | ms/batch  6.72 | loss  6.08 | ppl   436.78
# | epoch   1 |  1200/ 3481 batches | lr 20.00 | ms/batch  6.74 | loss  5.98 | ppl   397.01
# | epoch   1 |  1400/ 3481 batches | lr 20.00 | ms/batch  6.66 | loss  5.91 | ppl   368.80
# | epoch   1 |  1600/ 3481 batches | lr 20.00 | ms/batch  6.71 | loss  5.82 | ppl   336.56
# | epoch   1 |  1800/ 3481 batches | lr 20.00 | ms/batch  6.67 | loss  5.80 | ppl   331.73
# | epoch   1 |  2000/ 3481 batches | lr 20.00 | ms/batch  6.67 | loss  5.68 | ppl   292.96
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 2 --bptt 40
# Out:
# | epoch   1 |   200/ 2610 batches | lr 20.00 | ms/batch 11.85 | loss  7.65 | ppl  2090.21
# | epoch   1 |   400/ 2610 batches | lr 20.00 | ms/batch  8.27 | loss  6.79 | ppl   890.15
# | epoch   1 |   600/ 2610 batches | lr 20.00 | ms/batch  8.27 | loss  6.42 | ppl   611.80
# | epoch   1 |   800/ 2610 batches | lr 20.00 | ms/batch  8.30 | loss  6.20 | ppl   491.32
# | epoch   1 |  1000/ 2610 batches | lr 20.00 | ms/batch  8.31 | loss  6.06 | ppl   428.72
# | epoch   1 |  1200/ 2610 batches | lr 20.00 | ms/batch  8.26 | loss  5.96 | ppl   385.82
# | epoch   1 |  1400/ 2610 batches | lr 20.00 | ms/batch  8.30 | loss  5.91 | ppl   367.99
# | epoch   1 |  1600/ 2610 batches | lr 20.00 | ms/batch  8.29 | loss  5.75 | ppl   315.07
# | epoch   1 |  1800/ 2610 batches | lr 20.00 | ms/batch  8.28 | loss  5.70 | ppl   300.24
# | epoch   1 |  2000/ 2610 batches | lr 20.00 | ms/batch  8.30 | loss  5.56 | ppl   258.84
# ...

# %%
# !python main.py --cuda --epochs 6 --emsize 400 --nhid 400 --nlayers 2 --bptt 50
# Out:
# | epoch   1 |   200/ 2088 batches | lr 20.00 | ms/batch 13.35 | loss  7.66 | ppl  2124.70
# | epoch   1 |   400/ 2088 batches | lr 20.00 | ms/batch 10.20 | loss  6.79 | ppl   884.59
# | epoch   1 |   600/ 2088 batches | lr 20.00 | ms/batch 10.23 | loss  6.44 | ppl   626.09
# | epoch   1 |   800/ 2088 batches | lr 20.00 | ms/batch 10.20 | loss  6.21 | ppl   497.53
# | epoch   1 |  1000/ 2088 batches | lr 20.00 | ms/batch 10.17 | loss  6.04 | ppl   419.78
# | epoch   1 |  1200/ 2088 batches | lr 20.00 | ms/batch 10.21 | loss  5.94 | ppl   381.56
# | epoch   1 |  1400/ 2088 batches | lr 20.00 | ms/batch 10.18 | loss  5.82 | ppl   337.70
# | epoch   1 |  1600/ 2088 batches | lr 20.00 | ms/batch 10.18 | loss  5.68 | ppl   294.42
# | epoch   1 |  1800/ 2088 batches | lr 20.00 | ms/batch 10.19 | loss  5.69 | ppl   294.84
# | epoch   1 |  2000/ 2088 batches | lr 20.00 | ms/batch 10.23 | loss  5.55 | ppl   258.13
# ...

# %%
bptt_lengths = [10, 20, 30, 40, 50]
hidden_400_2_ppls = [145.26, 131.86, 128.95, 128.47, 131.01]

plt.plot(bptt_lengths, lstm_ppls, label='LSTM')
plt.plot(bptt_lengths, transformer_ppls, label='Transformer')
plt.plot(bptt_lengths, hidden_400_2_ppls, label='Hidden400Layer2')

plt.xlabel('BPTT Length')
plt.ylabel('Test PPL')
plt.title('BPTT Length VS Test PPL')
plt.legend()
plt.show()
